# %% [markdown]
# # Baseline Model and Exploration

# %% [markdown]
# Very TLDR : Create a dict of df (per bookingID) -> create feature using statistical measurement -> xgboost -> explain model with shap -> baseline achive 0.74 AUC & 0.65 AUC (if explainability is preferable)
#
# TLDR
# analyze all training data:
# -drop bookingID with multiple label
# -
#
# analyze per bookingID :
# -turn out there are some uncomplete data, some of them only 50% of total trip
# -erroneous data, maybe because some phone is not calibrated
# -Speed data might had already transformed, not sure (Only handful occurence above 40 Speed)
# -
#
#
#
# OK now move on, let the code say it all!

# %% [markdown]
# ## Table of Content

# %% [markdown]
# - [1. Import and Merge Data](#1)
#     - [1.1 Merge Data](#11)
#     - [1.2 Remove Outlier in Gyro, Speed, and Accelerometer Data](#12)
#     - [1.3 Create dict of df per bookingID](#13)
# - [2. Function](#2)
#     - [2.1 save_obj & load_obj](#21)
#     - [2.2 plot_all](#22)
#     - [2.3 statform](#23)
# - [3. Feature Engineering](#3)
#     - [3.1 Mean, Median, Std, Max, & Min](#31)s
#     - [3.2 Check & Remove Duplicate](#32)
#     - [3.3 Remove Outlier Second](#33)
# - [4. EDA](#4)
#     - [4.1 Sample Visualization](#41)
#     - [4.2 Pearson Correlation](#42)
#     - [4.3 Check Groupby Value](#43)
# - [5. Model Experiment](#5)
#     - [5.1 XGBoost](#51)
#     - [5.2 SHAP value analysis](#52)
# - [6. Summary of baseline model](#6)

# %% [markdown]
# <a id="1"></a>

# %% [markdown]
# ## 1. Import and Merge Data

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import glob
import gc
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import copy
import pickle
import swifter
import sys
pd.set_option('display.max_columns', 500)
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, precision_score, recall_score, roc_auc_score, roc_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc, classification_report
from sklearn.ensemble import RandomForestClassifier
import shap
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# /home/kurniawanekn/.local/lib/python3.5/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### 1.1 Merge Data

# %%
# %%time

# label file
train_data = pd.read_csv('safety/labels/part-00000-e9445087-aa0a-433b-a7f6-7f4c19d78ad6-c000.csv')

# feature file
files = glob.glob("safety/features/*.csv")
features = [pd.read_csv(f) for f in files]
all_features = pd.concat(features,ignore_index=True)

# del features
# gc.collect()
# Out:
# CPU times: user 29.7 s, sys: 8.46 s, total: 38.2 s
# Wall time: 38.2 s

# %%
# %%time
# change dtype for a bit of efficientcy
all_features = all_features.astype({
    'bookingID': 'int64', 
    'Accuracy':'float32',
    'Bearing':'float32',
    'acceleration_x':'float32',
    'acceleration_y':'float32',
    'acceleration_z':'float32',
    'gyro_x':'float32',
    'gyro_y':'float32',
    'gyro_z':'float32',
    'second':'float32',
    'Speed':'float32'
})

all_features.sort_values(['bookingID','second'], inplace=True) # sort here first for efficiency in the next process
all_features.reset_index(drop=True, inplace=True)
# Out:
# CPU times: user 21.1 s, sys: 4.26 s, total: 25.3 s
# Wall time: 25.3 s

# %% [markdown]
# ### 1.2 Remove Outlier in Gyro, Speed, and Accelerometer Data

# %%
# So many extreme value here, acceleration and gyro value shouldn't be that high
# Speed value after 75% jump over 10x in 100%
all_features.describe()
# Out:
#               bookingID     Accuracy      Bearing  acceleration_x  \
# count      16135561.000 16135561.000 16135561.000    16135561.000
# mean   818481856668.472       11.610      168.968           0.069
# std    495247577195.021       86.917      107.297           1.424
# min               0.000        0.750        0.000         -78.420
# 25%    377957122222.000        3.900       78.000          -0.508
# 50%    807453851666.000        4.250      168.870           0.061
# 75%   1254130450445.000        8.000      262.984           0.635
# max   1709396983975.000     6070.101      359.999          66.873
#
#        acceleration_y  acceleration_z       gyro_x       gyro_y       gyro_z  \
# count    16135561.000    16135561.000 16135561.000 16135561.000 16135561.000
# mean            4.469           0.894       -0.002        0.000       -0.000
# std             8.131           3.252        0.145        0.340        0.148
# ...

# %%
# no null
print(all_features.isnull().sum())

# so much data, 16 Million Row
print("Data Point : ",len(all_features))
# Out:
# bookingID         0
# Accuracy          0
# Bearing           0
# acceleration_x    0
# acceleration_y    0
# acceleration_z    0
# gyro_x            0
# gyro_y            0
# gyro_z            0
# second            0
# Speed             0
# dtype: int64
# Data Point :  16135561

# %%
# Remove Outlier at gyro and acceleration data
# We're gonna remove this first because if we don't, this outlier will be calculated in the feature engineering process
filt_df = all_features[['acceleration_x', 'acceleration_y',
       'acceleration_z', 'gyro_x', 'gyro_y', 'gyro_z']]

low = .0001
high = .9999
quant_df = filt_df.quantile([low, high])
print(quant_df)
# Out:
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0.000         -12.672         -15.740         -18.138  -2.940 -10.111  -3.604
# 1.000          12.560          40.483          25.395   2.999   9.778   3.568

# %%
# %%time
filt_df = filt_df.apply(lambda x: x[(x>quant_df.loc[low,x.name]) & (x < quant_df.loc[high,x.name])], axis=0)
filt_df = pd.concat([all_features.loc[:,['bookingID','second','Speed']], filt_df], axis=1)
filt_df.dropna(inplace=True)
# Out:
# CPU times: user 18.7 s, sys: 10.6 s, total: 29.3 s
# Wall time: 29.3 s

# %%
# Remove Outlier Speed
speed_cutoff = all_features.Speed.quantile([0.999999])[0.999999]

# Only a handful data after 40, this shouldn't be a kmph
# Data with high 'jump' to over 50 without previously reaching 40. We're just gonna use 40 as cutoff
all_features[all_features.Speed > 40]
# Out:
#               bookingID  Accuracy  Bearing  acceleration_x  acceleration_y  \
# 3325685    317827580025    32.000  285.924           0.342           9.310
# 3370067    326417514526    24.000   42.000           0.700           9.348
# 5114623    481036337322    32.000   21.000           0.323           9.989
# 5807711    566935683204    32.000  160.000          -0.776          10.157
# 5932536    584115552272    15.008  332.000          -0.874           9.195
# 6671562    661424963591     4.000  268.808           0.876          -8.104
# 6671563    661424963591     4.000  268.808           1.865         -10.602
# 6671565    661424963591     4.000  268.808           1.361         -11.549
# 6671566    661424963591     4.000  267.802           1.602          -9.995
# 6671567    661424963591     4.000  267.802           0.785          -8.193
# 6671568    661424963591     4.000  267.802           0.464          -9.208
# ...

# %%
filt_df.drop(filt_df[filt_df.Speed > 40].index, inplace=True)
filt_df.describe()
# Out:
#               bookingID         second        Speed  acceleration_x  \
# count      16118481.000   16118481.000 16118481.000    16118481.000
# mean   818457686831.063       3806.700        9.009           0.069
# std    495247327400.690    1437447.500        8.107           1.400
# min               0.000          0.000       -2.000         -12.672
# 25%    377957122220.000        241.000        1.020          -0.508
# 50%    807453851670.000        520.000        7.533           0.061
# 75%   1254130450445.000        862.000       15.484           0.634
# max   1709396983975.000 1495796736.000       39.979          12.560
#
#        acceleration_y  acceleration_z       gyro_x       gyro_y       gyro_z
# count    16118481.000    16118481.000 16118481.000 16118481.000 16118481.000
# mean            4.467           0.893       -0.002        0.001       -0.000
# std             8.117           3.219        0.122        0.229        0.111
# ...

# %%
filt_df.describe()
# Out:
#               bookingID         second        Speed  acceleration_x  \
# count      16118481.000   16118481.000 16118481.000    16118481.000
# mean   818457686831.063       3806.700        9.009           0.069
# std    495247327400.690    1437447.500        8.107           1.400
# min               0.000          0.000       -2.000         -12.672
# 25%    377957122220.000        241.000        1.020          -0.508
# 50%    807453851670.000        520.000        7.533           0.061
# 75%   1254130450445.000        862.000       15.484           0.634
# max   1709396983975.000 1495796736.000       39.979          12.560
#
#        acceleration_y  acceleration_z       gyro_x       gyro_y       gyro_z
# count    16118481.000    16118481.000 16118481.000 16118481.000 16118481.000
# mean            4.467           0.893       -0.002        0.001       -0.000
# std             8.117           3.219        0.122        0.229        0.111
# ...

# %%
print("Data Point : ",len(all_features))
print("Data Point After Filtering : ",len(filt_df))
print("Data Point Reduction : ",len(all_features)-len(filt_df))
# Out:
# Data Point :  16135561
# Data Point After Filtering :  16118481
# Data Point Reduction :  17080

# %% [markdown]
# ### 1.3 Create dict of df per bookingID

# %%
# %%time
"""
Create dict per bookingID for efficiency

Lookup bookingID in data is a time consuming for recursive opeeation, so we created it first here.
This process takes memory and time at first, but it will speed up our calculation later.
"""
df_dict = {}

for booking_id in train_data['bookingID']:

    #df_dict[booking_id] = all_features.loc[all_features.bookingID==booking_id]
    df_dict[booking_id] = copy.deepcopy(filt_df.loc[filt_df.bookingID==booking_id])
    #df_dict[booking_id] = all_features.query('bookingID == @booking_id')
    
df_dict.keys()
# Out:
# CPU times: user 8min 41s, sys: 632 ms, total: 8min 42s
# Wall time: 8min 42s

# %% [markdown]
# ## 2. Function

# %%
"""
This cell contain function to save object & load object

Used to save file to disk after aggregation to save time.
Will not be used in submission.
"""

def save_obj(obj, name ):
    with open('/jet/prs/aiforsea/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('/jet/prs/aiforsea/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
df_dict[0].head()
save_obj(df_dict,'df_dict')

# %%
def plot_all(df_dict,data,number):
    """
    Barbaric plot all column
    
    Will generate a side by side comparison of dangerous driving and safe driving data.
    Used for random check.
    
    Input:
    number      random number as you wish
    df_dict     list containing dataframe per bookingID
    data df     label data
    """
    d_df = data.loc[data.label==1].reset_index(drop=True)['bookingID']
    s_df = data.loc[data.label==0].reset_index(drop=True)['bookingID']
    
    
    d = df_dict[d_df[number]]
    s = df_dict[s_df[number]]
    print('dangerous (left) : id ',d_df[number])
    print('safe (right) : id ',s_df[number])


    y1 = 'acceleration_x'
    y2 = 'acceleration_y'
    y3 = 'acceleration_z'
    #y4 = 'Bearing'
    y5 = 'gyro_x'
    y6 = 'gyro_y'
    y7 = 'gyro_z'
    y8 = 'Speed'
    
    
    
    
    x_d = np.linspace(0,d.tail(1)['second'],d.tail(1)['second']+1).flatten()
    x_s = np.linspace(0,s.tail(1)['second'],s.tail(1)['second']+1).flatten()
    
    yd_secs = [-1] * (len(x_d))
    ys_secs = [-1] * (len(x_s))
    
    
    
    
    for i in d.second.tolist():
        yd_secs[int(i)] = i
    
    for i in s.second.tolist():
        ys_secs[int(i)] = i
    
    
    fig, axs = plt.subplots(nrows=9, ncols=2, figsize=(20,90))
    sns.lineplot(x="second", y=y1, data=d, ax=axs[0][0])
    sns.lineplot(x="second", y=y2, data=d, ax=axs[1][0])
    sns.lineplot(x="second", y=y3, data=d, ax=axs[2][0])
    #sns.lineplot(x="second", y=y4, data=d, ax=axs[3][0])
    sns.lineplot(x="second", y=y5, data=d, ax=axs[4][0])
    sns.lineplot(x="second", y=y6, data=d, ax=axs[5][0])
    sns.lineplot(x="second", y=y7, data=d, ax=axs[6][0])
    sns.lineplot(x="second", y=y8, data=d, ax=axs[7][0])
    sns.lineplot(x=x_d, y=yd_secs, data=d, ax=axs[8][0])
    
    
    
    sns.lineplot(x="second", y=y1, data=s, ax=axs[0][1])
    sns.lineplot(x="second", y=y2, data=s, ax=axs[1][1])
    sns.lineplot(x="second", y=y3, data=s, ax=axs[2][1])
    #sns.lineplot(x="second", y=y4, data=s, ax=axs[3][1])
    sns.lineplot(x="second", y=y5, data=s, ax=axs[4][1])
    sns.lineplot(x="second", y=y6, data=s, ax=axs[5][1])
    sns.lineplot(x="second", y=y7, data=s, ax=axs[6][1])
    sns.lineplot(x="second", y=y8, data=s, ax=axs[7][1])
    sns.lineplot(x=x_s, y=ys_secs, data=s, ax=axs[8][1])

# %%
def statform(booking_id,var):
    """
    Generate statistical measurement of a variable with the same bookingID.
    Use this in pandas apply.
    
    Input:
    booking_id      bookingID
    df_dict         list containing dataframe per bookingID
    data df         label data
    """
    booking_id = booking_id.bookingID
    std = df_dict[booking_id][var].std()
    maxx = df_dict[booking_id][var].max()
    minn = df_dict[booking_id][var].min()
    mean = df_dict[booking_id][var].mean()
    med = df_dict[booking_id][var].median()
    
    return std, maxx, minn, mean, med

# %% [markdown]
# ## 3. Feature Engineering

# %% [markdown]
# ### 3.1 Create Training Feature

# %%
# %%time
"""
Create Statistical Feature Per bookingID

Because of df_dict (dataframe per bookingID) we can calculate this feature faster.
Costly lookup operation is done only once. Accessing dict we previously built is also O(1) operation, another fast operation.
"""
cols = ['acceleration_x', 'acceleration_y', 'acceleration_z', 'gyro_x', 'gyro_y', 'gyro_z', 'second', 'Speed'] 

for col in cols:
    std_str = 'std_' + col
    max_str = 'max_' + col
    min_str = 'min_' + col
    mean_str = 'mean_' + col
    med_str = 'median_' + col
    
    train_data[[std_str, max_str, min_str, mean_str, med_str]] = train_data.apply(lambda x:statform(x,col), axis = 1, result_type='expand')
# Out:
# CPU times: user 2min 49s, sys: 332 ms, total: 2min 49s
# Wall time: 2min 49s

# %% [markdown]
# ### 3.2 Check, Remove Duplicate & NAN

# %%
# 1:3 ratio, a little bit imbalanced
train_data.label.value_counts()
# Out:
# 0    15017
# 1     5001
# Name: label, dtype: int64

# %%
# No duplicate data
train_data[train_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [bookingID, label, std_acceleration_x, max_acceleration_x, min_acceleration_x, mean_acceleration_x, median_acceleration_x, std_acceleration_y, max_acceleration_y, min_acceleration_y, mean_acceleration_y, median_acceleration_y, std_acceleration_z, max_acceleration_z, min_acceleration_z, mean_acceleration_z, median_acceleration_z, std_gyro_x, max_gyro_x, min_gyro_x, mean_gyro_x, median_gyro_x, std_gyro_y, max_gyro_y, min_gyro_y, mean_gyro_y, median_gyro_y, std_gyro_z, max_gyro_z, min_gyro_z, mean_gyro_z, median_gyro_z, std_second, max_second, min_second, mean_second, median_second, std_Speed, max_Speed, min_Speed, mean_Speed, median_Speed]
# Index: []

# %%
# double bookingID have different label. to avoid confusion we just gonna drop it later
train_data.loc[train_data.bookingID.isin(train_data.bookingID[train_data.bookingID.duplicated()].tolist())].sort_values(['bookingID'])
# Out:
#            bookingID  label  std_acceleration_x  max_acceleration_x  \
# 12602             13      1               0.798               4.034
# 12463             13      0               0.798               4.034
# 2351    154618822837      1               0.760               4.789
# 5295    154618822837      0               0.760               4.789
# 11215   223338299461      1               1.213               7.068
# 6212    223338299461      0               1.213               7.068
# 19936   395136991308      0               0.613               2.502
# 6121    395136991308      1               0.613               2.502
# 17623   403726925929      1               0.887               4.180
# 8472    403726925929      0               0.887               4.180
# 2858    455266533495      1               0.532               3.486
# 10778   455266533495      0               0.532               3.486
# 18027   481036337234      0               0.863               3.375
# ...

# %%
# there is a double data on label but not on feature, were just gonna drop the double row in label
train_data.drop(train_data.index[train_data.loc[train_data.bookingID.duplicated()].index.tolist()], inplace=True)

# %%
# This nan value mean all of some bookingID data contain outlier. All of its data got deleted in previous step.
# We're gonna drop this empty row
train_data.isnull().sum()
# Out:
# bookingID                0
# label                    0
# std_acceleration_x       1
# max_acceleration_x       0
# min_acceleration_x       0
# mean_acceleration_x      0
# median_acceleration_x    0
# std_acceleration_y       1
# max_acceleration_y       0
# min_acceleration_y       0
# mean_acceleration_y      0
# median_acceleration_y    0
# std_acceleration_z       1
# max_acceleration_z       0
# min_acceleration_z       0
# mean_acceleration_z      0
# median_acceleration_z    0
# std_gyro_x               1
# max_gyro_x               0
# min_gyro_x               0
# mean_gyro_x              0
# median_gyro_x            0
# std_gyro_y               1
# max_gyro_y               0
# min_gyro_y               0
# mean_gyro_y              0
# median_gyro_y            0
# std_gyro_z               1
# max_gyro_z               0
# min_gyro_z               0
# mean_gyro_z              0
# median_gyro_z            0
# std_second               1
# max_second               0
# ...

# %%
train_data.dropna(inplace=True)
len(train_data)
# Out:
# 19999

# %% [markdown]
# ### 3.3 Remove Outlier Second

# %%
# Didn't make sense, we're removing this
train_data.loc[train_data.max_second>10000]
# Out:
#            bookingID  label  std_acceleration_x  max_acceleration_x  \
# 2813   1460288880770      0               0.531               3.677
# 6431   1108101562401      0               0.698               2.605
# 8590   1434519076976      0               0.829               4.022
# 15361   858993459333      0               0.769               2.854
# 17480  1503238553722      0               0.705               3.916
#
#        min_acceleration_x  mean_acceleration_x  median_acceleration_x  \
# 2813               -2.337                0.439                  0.460
# 6431               -3.141                0.158                  0.182
# 8590               -5.210                0.139                  0.230
# 15361              -3.965               -0.113                 -0.110
# 17480              -2.022                0.286                  0.237
#
#        std_acceleration_y  max_acceleration_y  min_acceleration_y  \
# ...

# %%
train_data.drop(train_data.index[train_data.loc[train_data.max_second>10000].index.tolist()], inplace=True)

# %%
save_obj(train_data,'train_data')
train_data.head()
# Out:
#        bookingID  label  std_acceleration_x  max_acceleration_x  \
# 0   111669149733      0               0.589               2.615
# 1   335007449205      1               1.107               5.617
# 2   171798691856      0               0.588               2.897
# 3  1520418422900      0               0.838               8.741
# 4   798863917116      0               1.558              11.065
#
#    min_acceleration_x  mean_acceleration_x  median_acceleration_x  \
# 0              -2.825                0.114                  0.194
# 1              -4.159                0.233                  0.186
# 2              -1.864                0.279                  0.244
# 3              -8.100               -0.534                 -0.581
# 4              -8.344                0.134                  0.239
#
#    std_acceleration_y  max_acceleration_y  min_acceleration_y  \
# 0               0.422              14.675               7.164
# ...

# %% [markdown]
# ## 4. EDA

# %% [markdown]
# ### 4.1 Sample Visulization

# %%
plot_all(df_dict,train_data,1)

"""
In this comparison, we see acceleration & gyro have a greater magnitude in dangerous data.
This is aligned with my assumption that dangerous driving gyro & accelerometer have greater difference from mean.
Also notice some missing data in both type.
"""
# Out:
# dangerous (left) : id  274877906944
# safe (right) : id  171798691856
# /home/kurniawanekn/.local/lib/python3.5/site-packages/ipykernel_launcher.py:35: DeprecationWarning: object of type <class 'pandas.core.series.Series'> cannot be safely interpreted as an integer.
# /home/kurniawanekn/.local/lib/python3.5/site-packages/ipykernel_launcher.py:36: DeprecationWarning: object of type <class 'pandas.core.series.Series'> cannot be safely interpreted as an integer.
# '\nIn this comparison, we see acceleration & gyro have a greater magnitude in dangerous data.\nThis is aligned with my assumption that dangerous driving gyro & accelerometer have greater difference from mean.\nAlso notice some missing data in both type.\n'

# %%
plot_all(df_dict,train_data,3)

"""
In this comparison, previous assumption is reversed.
Now acceleration & gyro in dangerous driving has a lower magnitude than safe.
"""
# Out:
# dangerous (left) : id  841813590179
# safe (right) : id  798863917116
# /home/kurniawanekn/.local/lib/python3.5/site-packages/ipykernel_launcher.py:35: DeprecationWarning: object of type <class 'pandas.core.series.Series'> cannot be safely interpreted as an integer.
# /home/kurniawanekn/.local/lib/python3.5/site-packages/ipykernel_launcher.py:36: DeprecationWarning: object of type <class 'pandas.core.series.Series'> cannot be safely interpreted as an integer.
# '\nIn this comparison, previous assumption is reversed.\nNow acceleration & gyro in dangerous driving has a lower magnitude than safe.\n'

# %% [markdown]
# ### 4.2 Pearson Correlation

# %%
import seaborn as sns
corr = train_data.corr()
plt.figure(figsize = (20,20))


# ax = sns.heatmap(corr, 
#             xticklabels=corr.columns.values,
#             yticklabels=corr.columns.values)
corr
# Out:
#                        bookingID  label  std_acceleration_x  \
# bookingID                  1.000  0.037               0.019
# label                      0.037  1.000               0.160
# std_acceleration_x         0.019  0.160               1.000
# max_acceleration_x         0.017  0.163               0.648
# min_acceleration_x        -0.014 -0.158              -0.653
# mean_acceleration_x       -0.002 -0.006              -0.022
# median_acceleration_x     -0.002 -0.005              -0.015
# std_acceleration_y         0.021  0.163               0.741
# max_acceleration_y         0.009  0.051               0.219
# min_acceleration_y         0.001 -0.057              -0.147
# mean_acceleration_y        0.005 -0.007               0.028
# median_acceleration_y      0.004 -0.006               0.028
# std_acceleration_z         0.021  0.174               0.734
# max_acceleration_z         0.021  0.141               0.423
# min_acceleration_z         0.001 -0.106              -0.376
# ...

# %% [markdown]
# ### 4.3 Check Groupby Value

# %%
# There are slight difference in gyro and acceleration, both 
train_data.groupby('label').mean()
# Out:
#              bookingID  std_acceleration_x  max_acceleration_x  \
# label
# 0     805623209935.162               0.834               3.893
# 1     848120559912.938               0.986               4.651
#
#        min_acceleration_x  mean_acceleration_x  median_acceleration_x  \
# label
# 0                  -3.797                0.076                  0.082
# 1                  -4.550                0.062                  0.069
#
#        std_acceleration_y  max_acceleration_y  min_acceleration_y  \
# label
# 0                   0.724               8.185               1.010
# 1                   0.971               9.153              -0.076
#
#        mean_acceleration_y  median_acceleration_y  std_acceleration_z  \
# label
# 0                    4.609                  4.613               1.013
# 1                    4.485                  4.493               1.253
#
#        max_acceleration_z  min_acceleration_z  mean_acceleration_z  \
# label
# ...

# %%
# %%time 
train_data.groupby('label').min()
# Out:
# CPU times: user 16 ms, sys: 0 ns, total: 16 ms
# Wall time: 13.1 ms
#        bookingID  std_acceleration_x  max_acceleration_x  min_acceleration_x  \
# label
# 0              0               0.007              -7.121             -12.654
# 1              1               0.050              -7.004             -12.672
#
#        mean_acceleration_x  median_acceleration_x  std_acceleration_y  \
# label
# 0                   -9.819                 -9.812               0.010
# 1                   -9.757                 -9.774               0.032
#
#        max_acceleration_y  min_acceleration_y  mean_acceleration_y  \
# label
# 0                  -9.085             -15.733              -10.028
# 1                  -8.906             -15.738              -10.066
#
#        median_acceleration_y  std_acceleration_z  max_acceleration_z  \
# label
# 0                    -10.021               0.011              -8.326
# 1                    -10.060               0.076              -7.418
#
# ...

# %%
train_data.groupby('label').max()
# Out:
#            bookingID  std_acceleration_x  max_acceleration_x  \
# label
# 0      1700807049407               5.662              12.559
# 1      1709396983975               6.883              12.560
#
#        min_acceleration_x  mean_acceleration_x  median_acceleration_x  \
# label
# 0                   8.159               10.006                  9.987
# 1                   7.536                9.879                  9.881
#
#        std_acceleration_y  max_acceleration_y  min_acceleration_y  \
# label
# 0                   9.613              40.482              31.322
# 1                   8.326              40.461              16.288
#
#        mean_acceleration_y  median_acceleration_y  std_acceleration_z  \
# label
# 0                   38.771                 39.248               7.237
# 1                   34.956                 35.522               9.205
#
#        max_acceleration_z  min_acceleration_z  mean_acceleration_z  \
# label
# ...

# %% [markdown]
# ## 5. Model Experiment

# %%
# fast import. Please run above code and delete this cell if df_dict.pkl and data.pkl didn't exist 
df_dict = load_obj('df_dict') # dict contain dataframe per bookingID, sorted by time ascending
train_data = load_obj('train_data') # label data + additional statistic transformation per bookingID

# %% [markdown]
# ### 5.1 XGBoost
#
# +Fast
# +No feature selection needed
# +Easily Analyze feature using SHAP
# -Prone to overfit-->we use early stopping

# %%
# %%time
X = train_data.drop('label', axis=1)

# drop column that didn't make any sense
X.drop('bookingID', axis=1, inplace=True)
X.drop(['mean_second','median_second','std_second','min_second'], axis=1, inplace=True) # no meaning, represented by max second
X.drop(['min_Speed'], axis=1, inplace=True) # I think this is unrelated
X.drop(['mean_Speed'], axis=1, inplace=True) # Median used as robust mean estimation
#X.drop(['mean_Speed','max_Speed','max_second'], axis=1, inplace=True)





Y = train_data['label']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)


model = XGBClassifier(n_estimators=10000, objective= 'binary:logistic')
#model = DecisionTreeClassifier()
#model = LogisticRegression()
#model = RandomForestClassifier()

eval_set  = [(X_train,y_train), (X_test,y_test)]
model.fit(X_train, y_train, eval_set=eval_set, eval_metric="auc", early_stopping_rounds=30)

#model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_scores = model.predict_proba(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

print("ROC_AUC: %.2f%%" % (roc_auc_score(y_test.values, y_scores[:,1])*100))
print(classification_report(y_test, y_pred))
# Out:
# [0]	validation_0-auc:0.677985	validation_1-auc:0.668943
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 30 rounds.
# [1]	validation_0-auc:0.693982	validation_1-auc:0.689764
# [2]	validation_0-auc:0.695369	validation_1-auc:0.689689
# [3]	validation_0-auc:0.695481	validation_1-auc:0.689854
# [4]	validation_0-auc:0.706182	validation_1-auc:0.700627
# [5]	validation_0-auc:0.710086	validation_1-auc:0.702924
# [6]	validation_0-auc:0.712833	validation_1-auc:0.70476
# [7]	validation_0-auc:0.713536	validation_1-auc:0.704907
# [8]	validation_0-auc:0.715548	validation_1-auc:0.7069
# [9]	validation_0-auc:0.717255	validation_1-auc:0.707527
# [10]	validation_0-auc:0.718832	validation_1-auc:0.707775
# [11]	validation_0-auc:0.718806	validation_1-auc:0.707717
# [12]	validation_0-auc:0.719986	validation_1-auc:0.70967
# [13]	validation_0-auc:0.720868	validation_1-auc:0.709658
# ...

# %% [markdown]
# ### 5.2 SHAP value analysis

# %%
# Compute ROC curve and ROC area for each class
n_classes = 2


fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test.values, y_scores[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
# fpr["micro"], tpr["micro"], _ = roc_curve(y_test.values, y_scores[:, i])
# roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure()
lw = 2
plt.plot(fpr[1], tpr[1], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[1])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
shap.dependence_plot("max_second", shap_values, X_test)

# %%
shap.dependence_plot("max_Speed", shap_values, X_test)

# %%
shap.dependence_plot("std_acceleration_z", shap_values, X_test)

# %%
shap.dependence_plot("std_acceleration_y", shap_values, X_test)

# %%
shap.initjs()
index = 12
shap.force_plot(explainer.expected_value, shap_values[index,:], X_test.iloc[index,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
index = 0
shap.force_plot(explainer.expected_value, shap_values[index,:], X_test.iloc[index,:])
# Out:
# <div id='i7F01ZYA4TA5APCCIYN5N'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.initjs()
index = 1
shap.force_plot(explainer.expected_value, shap_values[index,:], X_test.iloc[index,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %%
shap.initjs()
index = 2
shap.force_plot(explainer.expected_value, shap_values[index,:], X_test.iloc[index,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";funct
# ...

# %% [markdown]
# ## 6. Summary of baseline model

# %%
pd.Series(y_pred).value_counts(normalize=True)
# Out:
# 0   0.928
# 1   0.072
# dtype: float64

# %%
pd.Series(y_test).value_counts(normalize=True)
# Out:
# 0   0.747
# 1   0.253
# Name: label, dtype: float64

# %%
filt_df.describe()
# Out:
#               bookingID         second        Speed  acceleration_x  \
# count      16118481.000   16118481.000 16118481.000    16118481.000
# mean   818457686831.063       3806.700        9.009           0.069
# std    495247327400.690    1437447.500        8.107           1.400
# min               0.000          0.000       -2.000         -12.672
# 25%    377957122220.000        241.000        1.020          -0.508
# 50%    807453851670.000        520.000        7.533           0.061
# 75%   1254130450445.000        862.000       15.484           0.634
# max   1709396983975.000 1495796736.000       39.979          12.560
#
#        acceleration_y  acceleration_z       gyro_x       gyro_y       gyro_z
# count    16118481.000    16118481.000 16118481.000 16118481.000 16118481.000
# mean            4.467           0.893       -0.002        0.001       -0.000
# std             8.117           3.219        0.122        0.229        0.111
# ...

# %%
all_features.quantile(0.9999)
# Out:
# bookingID        1709396983966.000
# Accuracy                  2669.000
# Bearing                    359.871
# acceleration_x              12.560
# acceleration_y              40.483
# acceleration_z              25.395
# gyro_x                       2.999
# gyro_y                       9.778
# gyro_z                       3.568
# second                    6819.444
# Speed                       33.514
# Name: 0.9999, dtype: float64

# %%
all_features.describe()
# Out:
#               bookingID     Accuracy      Bearing  acceleration_x  \
# count      16135561.000 16135561.000 16135561.000    16135561.000
# mean   818481856668.472       11.610      168.968           0.069
# std    495247577195.021       86.917      107.297           1.424
# min               0.000        0.750        0.000         -78.420
# 25%    377957122222.000        3.900       78.000          -0.508
# 50%    807453851666.000        4.250      168.870           0.061
# 75%   1254130450445.000        8.000      262.984           0.635
# max   1709396983975.000     6070.101      359.999          66.873
#
#        acceleration_y  acceleration_z       gyro_x       gyro_y       gyro_z  \
# count    16135561.000    16135561.000 16135561.000 16135561.000 16135561.000
# mean            4.469           0.894       -0.002        0.000       -0.000
# std             8.131           3.252        0.145        0.340        0.148
# ...
